# %%
import pandas as pd
df =pd.read_csv("../files/summary/complete.csv")
df
# Out:
#      Unnamed: 0           State  Candidate ID                         Name  \
# 0             0  Aguascalientes             1         Jorge Álvarez Máynez
# 1             1  Aguascalientes             2   Bertha Xóchitl Gálvez Ruíz
# 2             2  Aguascalientes             3      Claudia Sheinbaum Pardo
# 3             3  Aguascalientes             4  Candidaturas no registradas
# 4             4  Aguascalientes             5                  Votos nulos
# ..          ...             ...           ...                          ...
# 155         155       Zacatecas             1         Jorge Álvarez Máynez
# 156         156       Zacatecas             2   Bertha Xóchitl Gálvez Ruíz
# 157         157       Zacatecas             3      Claudia Sheinbaum Pardo
# 158         158       Zacatecas             4  Candidaturas no registradas
# 159         159       Zacatecas             5                  Votos nulos
#
#      Total Votes  Percentage  National Votes  Abroad Votes
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Candidate ID   Total Votes  Percentage  National Votes  \
# count  160.000000    160.000000  1.600000e+02  160.000000    1.600000e+02
# mean    79.500000      3.000000  3.506742e+05    0.200305    3.495219e+05
# std     46.332134      1.418654  6.155453e+05    0.229887    6.135267e+05
# min      0.000000      1.000000  4.460000e+02    0.000956    4.460000e+02
# 25%     39.750000      2.000000  1.797400e+04    0.021431    1.795575e+04
# 50%     79.500000      3.000000  1.017690e+05    0.095964    1.014040e+05
# 75%    119.250000      4.000000  4.085180e+05    0.332199    4.065178e+05
# max    159.000000      5.000000  4.910698e+06    0.801222    4.904901e+06
#
#        Abroad Votes
# count    160.000000
# mean    1152.350000
# std     3024.886029
# min        0.000000
# 25%       17.000000
# 50%       97.500000
# 75%     1091.000000
# max    29737.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      160 non-null    int64
#  1   State           160 non-null    object
#  2   Candidate ID    160 non-null    int64
#  3   Name            160 non-null    object
#  4   Total Votes     160 non-null    int64
#  5   Percentage      160 non-null    float64
#  6   National Votes  160 non-null    int64
#  7   Abroad Votes    160 non-null    int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 10.1+ KB

# %%
del df['Unnamed: 0']
del df['Candidate ID']
result = df.loc[df.groupby('State')['Percentage'].idxmax()]
result
# Out:
#                    State                        Name  Total Votes  Percentage  \
# 1         Aguascalientes  Bertha Xóchitl Gálvez Ruíz       294218    0.461466
# 7        Baja California     Claudia Sheinbaum Pardo       855022    0.653375
# 12   Baja California Sur     Claudia Sheinbaum Pardo       174176    0.587398
# 17              Campeche     Claudia Sheinbaum Pardo       238025    0.607920
# 32               Chiapas     Claudia Sheinbaum Pardo      1508000    0.712269
# 37             Chihuahua     Claudia Sheinbaum Pardo       736541    0.526231
# 42      Ciudad De México     Claudia Sheinbaum Pardo      2986741    0.553621
# 22              Coahuila     Claudia Sheinbaum Pardo       808040    0.532821
# 27                Colima     Claudia Sheinbaum Pardo       182722    0.539529
# 47               Durango     Claudia Sheinbaum Pardo       402186    0.578516
# 52            Guanajuato     Claudia Sheinbaum Pardo      1224110    0.468781
# ...
